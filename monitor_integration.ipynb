# %%
import rebound
from rebound import hash as h

# %%
# Import simulation archive
sa = rebound.Simulationarchive("outputs/orbital_integration/archive.bin")

print("Number of snapshots: {}".format(len(sa)))
print("Time of first and last snapshot: {:.1f}, {:.1f}".format(sa.tmin, sa.tmax))

N_pl = 8 # Total number of bodies
N_tp = 15 # Number of test particles
# Out:
# Number of snapshots: 8821
# Time of first and last snapshot: 0.0, 8820000.0

# %%
# Access each snapshot in the simulation

# Earliest snapshot
sim = sa[0]
rebound.OrbitPlot(sim, unitlabel = "[AU]", xlim = [-5, 5], ylim = [-6, 6],
                  color = (N_pl - 1) * ["black"] + N_tp * ["red"])

# %%
# Latest snapshot
sim = sa[-1]
rebound.OrbitPlot(sim, unitlabel = "[AU]", xlim = [-5, 5], ylim = [-6, 6],
                  color = (N_pl - 1) * ["black"] + N_tp * ["red"])
sim.status()
# Out:
# ---------------------------------
# REBOUND version:     	4.4.2
# REBOUND built on:    	Jul 15 2024 18:47:33
# Number of particles: 	9
# Selected integrator: 	mercurius
# Simulation time:     	8.8200000029835869e+06
# Current timestep:    	0.024608
# ---------------------------------
# <rebound.particle.Particle object at 0x1aa5a8243d0, m=0.9999999999950272 x=-0.0039692531989207035 y=-0.006824529877495742 z=0.0001759021174613054 vx=0.0028116384585426357 vy=-0.000657772866114223 vz=-7.438595992753907e-05>
# <rebound.particle.Particle object at 0x1aa5a6ef7d0, m=2.447838287784771e-06 x=0.15300207400459698 y=-0.724344579974683 z=-0.0023779320802980687 vx=7.061217465446845 vy=1.7500224837424483 vz=-0.17782595611834365>
# <rebound.particle.Particle object at 0x1aa5a8243d0, m=3.0404326489511185e-06 x=-0.46378268675032114 y=-0.9109840883052582 z=-0.009432012681422151 vx=5.465326209656264 vy=-2.9151341542773435 vz=-0.15120151917540314>
# <rebound.particle.Particle object at 0x1aa5a6ef7d0, m=3.2271560828978514e-07 x=-1.169462874779464 y=0.9245445157868962 z=0.1624026646492716 vx=-3.4917634810136313 vy=-3.781669705257891 vz=0.4396575048763921>
# <rebound.particle.Particle object at 0x1aa5a8243d0, m=0.0009547919099366768 x=-0.25292532787700833 y=5.07185530223113 z=-0.06550972118158652 vx=-2.8148566355782236 vy=0.016043454168448254 vz=0.07189979607083909>
# <rebound.particle.Particle object at 0x1aa5a6ef7d0, m=0.0002858856700231729 x=9.520650295927577 y=1.6859865014163433 z=-0.28671311787724946 vx=-0.341631147588906 vy=1.977218163381597 vz=0.024437526591262245>
# <rebound.particle.Particle object at 0x1aa5a8243d0, m=4.366249613200406e-05 x=20.061505605093057 y=1.602571757083243 z=-0.5074877937129009 vx=-0.12577944492441023 vy=1.3601833614298113 vz=-0.03326165690707436>
# <rebound.particle.Particle object at 0x1aa5a6ef7d0, m=5.151383772628957e-05 x=11.926976570229009 y=27.84176766931718 z=-0.17949588131693153 vx=-1.0414997541989865 vy=0.4582703907474237 vz=0.018552053931702037>
# <rebound.particle.Particle object at 0x1aa5a8243d0, m=0.0 x=-450.62401113637674 y=-801.7901735574358 z=85.63730374413166 vx=-0.06425546603479328 vy=-0.15874517728172094 vz=0.007201120771583687>
# ---------------------------------
# The following fields have non-default values:
# t:
# < 0.000000e+00
# ---
# > 8.820000e+06
# G:
# < 1.000000e+00
# ---
# > 3.947693e+01
# dt:
# < 1.000000e-03
# ---
# > 2.460765e-02
# N:
# < 0
# ---
# > 9
# N_active:
# < -1
# ---
# > 8
# exact_finish_time:
# < 1
# ---
# > 0
# exit_max_distance:
# < 0.000000e+00
# ---
# > 1.000000e+03
# simulationarchive_auto_interval:
# < 0.000000e+00
# ---
# > 1.000000e+03
# simulationarchive_next:
# < 0.000000e+00
# ---
# > 8.821000e+06
# collision:
# < 0
# ---
# > 1
# integrator:
# < 0
# ---
# > 9
# gravity:
# < 1
# ---
# > 4
# ri_ias15.iterations_max_exceeded:
# < 0
# ---
# > 7
# ri_mercurius.recalculate_coordinates_this_timestep:
# < 0
# ---
# > 1
# walltime:
# < 0.000000e+00
# ---
# > 1.386211e+03
# walltime_last_steps:
# < 0.000000e+00
# ---
# > 2.443379e-06
# python_unit_l:
# < 0
# ---
# > 12937928
# python_unit_m:
# < 0
# ---
# > 2145773914
# python_unit_t:
# < 0
# ---
# > 1864791206
# ri_mercurius.com_pos:
# < (24 bytes, values not printed)
# ---
# > (24 bytes, values not printed)
# ri_mercurius.com_vel:
# < (24 bytes, values not printed)
# ---
# > (24 bytes, values not printed)
# steps_done:
# < 0
# ---
# > 358425071
# dt_last_done:
# < 0.000000e+00
# ---
# > 2.460765e-02
# rand_seed:
# < 231964
# ---
# > 2922586390
# max_radius0:
# < 0.000000e+00
# ---
# > 6.684590e-09
# max_radius1:
# < 0.000000e+00
# ---
# > 6.684590e-09
# particles:
# > (1152 bytes, values not printed)
# ri_ias15.at:
# > (216 bytes, values not printed)
# ri_ias15.x0:
# > (216 bytes, values not printed)
# ri_ias15.v0:
# > (216 bytes, values not printed)
# ri_ias15.a0:
# > (216 bytes, values not printed)
# ri_ias15.csx:
# > (216 bytes, values not printed)
# ri_ias15.csv:
# > (216 bytes, values not printed)
# ri_ias15.csa0:
# > (216 bytes, values not printed)
# ri_ias15.g:
# > (1512 bytes, values not printed)
# ri_ias15.b:
# > (1512 bytes, values not printed)
# ri_ias15.csb:
# > (1512 bytes, values not printed)
# ri_ias15.e:
# > (1512 bytes, values not printed)
# ri_ias15.br:
# > (1512 bytes, values not printed)
# ri_ias15.er:
# > (1512 bytes, values not printed)
# ri_mercurius.dcrit:
# > (184 bytes, values not printed)

# %%
# Convert values into instantaneous orbital elements
# AKA Osculating Orbital Elements
orbits = sim.orbits()
for orbit in orbits:
    print(orbit)
# Out:
# <rebound.Orbit instance, a=0.7233285093769538 e=0.031662880701399165 inc=0.02478821181559286 Omega=1.645468282737684 omega=5.38982420040754 f=4.1757005508474805>
# <rebound.Orbit instance, a=1.0000035723826763 e=0.02454481424245257 inc=0.026007631513737375 Omega=0.7276471424770866 omega=1.2967120376823953 f=2.2176764886636633>
# <rebound.Orbit instance, a=1.5236594106704067 e=0.08169596621888825 inc=0.1329165037848323 Omega=1.5176525605880327 omega=5.770693519055748 f=1.4664116978396775>
# <rebound.Orbit instance, a=5.20192290591696 e=0.058952641988104 inc=0.029285754190339852 Omega=2.0764653366755876 omega=4.590802904783857 f=1.2355239413779486>
# <rebound.Orbit instance, a=9.549041291092626 e=0.014013302084236498 inc=0.03209237593619116 Omega=1.352823775791627 omega=2.243347091257043 f=2.8622285119710016>
# <rebound.Orbit instance, a=19.194554541622427 e=0.050323007017915554 inc=0.03525855833807552 Omega=2.4249333480222153 omega=0.5710098488004389 f=3.3673350596827274>
# <rebound.Orbit instance, a=30.06532963062501 e=0.01225121941305146 inc=0.01740134526538404 Omega=1.5135340721190451 omega=3.695854217715365 f=2.239811167092892>
# <rebound.Orbit instance, a=703.2838867139426 e=0.9915679012621629 inc=0.3862677730611513 Omega=1.2897591565812796 omega=6.128286516682212 f=3.0478514712068936>
